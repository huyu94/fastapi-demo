# %%
# !pip install requests

# %%
import requests
url = 'http://127.0.0.1:8009/items/' 
headers = {"Cookie":"cka=111a;ckb=111b"}
cookies = {"abs_id":"your_ads_id_value"}
res = requests.get(url, cookies=cookies) 
res.text
# Out:
# '{"detail":[{"type":"missing","loc":["cookie","ads_id"],"msg":"Field required","input":null}]}'
